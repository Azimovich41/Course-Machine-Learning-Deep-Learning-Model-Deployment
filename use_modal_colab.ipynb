# %%
### 10.11.2025 14:00

# %%
import numpy as np

# %%
import pickle

# %%
# !ls
# Out:
# sample_data

# %%
# !wget https://github.com/Azimovich41/Course-Machine-Learning-Deep-Learning-Model-Deployment/raw/refs/heads/main/classifier.pickle
# Out:
# --2025-11-12 06:48:04--  https://github.com/Azimovich41/Course-Machine-Learning-Deep-Learning-Model-Deployment/raw/refs/heads/main/classifier.pickle
# Resolving github.com (github.com)... 140.82.114.3
# Connecting to github.com (github.com)|140.82.114.3|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://raw.githubusercontent.com/Azimovich41/Course-Machine-Learning-Deep-Learning-Model-Deployment/refs/heads/main/classifier.pickle [following]
# --2025-11-12 06:48:05--  https://raw.githubusercontent.com/Azimovich41/Course-Machine-Learning-Deep-Learning-Model-Deployment/refs/heads/main/classifier.pickle
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 2195 (2.1K) [application/octet-stream]
# Saving to: ‘classifier.pickle’
#
# classifier.pickle   100%[===================>]   2.14K  --.-KB/s    in 0s
#
# 2025-11-12 06:48:05 (33.7 MB/s) - ‘classifier.pickle’ saved [2195/2195]

# %%
# !ls
# Out:
# classifier.pickle  sample_data

# %%
# !wget https://github.com/Azimovich41/Course-Machine-Learning-Deep-Learning-Model-Deployment/raw/refs/heads/main/sc.pickle
# Out:
# --2025-11-12 06:48:05--  https://github.com/Azimovich41/Course-Machine-Learning-Deep-Learning-Model-Deployment/raw/refs/heads/main/sc.pickle
# Resolving github.com (github.com)... 140.82.114.3
# Connecting to github.com (github.com)|140.82.114.3|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://raw.githubusercontent.com/Azimovich41/Course-Machine-Learning-Deep-Learning-Model-Deployment/refs/heads/main/sc.pickle [following]
# --2025-11-12 06:48:05--  https://raw.githubusercontent.com/Azimovich41/Course-Machine-Learning-Deep-Learning-Model-Deployment/refs/heads/main/sc.pickle
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 498 [application/octet-stream]
# Saving to: ‘sc.pickle’
#
# sc.pickle           100%[===================>]     498  --.-KB/s    in 0s
#
# 2025-11-12 06:48:05 (6.35 MB/s) - ‘sc.pickle’ saved [498/498]

# %%
# !ls
# Out:
# classifier.pickle  sample_data	sc.pickle

# %%
# 12.11.2025

# %%
classifier_colab = pickle.load(open('classifier.pickle', 'rb'))
# Out:
# /usr/local/lib/python3.12/dist-packages/sklearn/base.py:442: InconsistentVersionWarning: Trying to unpickle estimator KNeighborsClassifier from version 1.6.1 when using version 1.7.2. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(

# %%
#!pip install scikit-learn --upgrade

# %%
# !pip install numpy --upgrade

# %%
scaler_colab = pickle.load(open('sc.pickle', 'rb'))
# Out:
# /usr/local/lib/python3.12/dist-packages/sklearn/base.py:442: InconsistentVersionWarning: Trying to unpickle estimator StandardScaler from version 1.6.1 when using version 1.7.2. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(

# %%
new_pred = classifier_colab.predict(scaler_colab.transform(np.array([[40, 20000]])))

# %%
new_pred
# Out:
# array([0])

# %%
new_pred_proba = classifier_colab.predict_proba(scaler_colab.transform(np.array([[40, 20000]])))[:, 1]

# %%
new_pred_proba
# Out:
# array([0.2])

# %%
new_pred_2 = classifier_colab.predict(scaler_colab.transform(np.array([[42, 50000]])))
new_pred_proba_2 = classifier_colab.predict_proba(scaler_colab.transform(np.array([[42, 50000]])))[:, 1]

# %%
new_pred_proba_2
# Out:
# array([0.8])
